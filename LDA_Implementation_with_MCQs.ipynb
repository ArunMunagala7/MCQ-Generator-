# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunMunagala7/MCQ-Generator-/blob/main/LDA_Implementation_with_MCQs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing libraries

# %%
# !pip install -q pypdf langchain_community langchain openai sentence-transformers chromadb langchain_cohere tiktoken gdown
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 40.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 28.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.4 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (4.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.10.0)

# %% [markdown]
# Importing needed libraries and the LdaModel

# %%
import gensim
import nltk
from gensim import corpora
from gensim.models import LdaModel
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from pypdf import PdfReader
from langchain.chains import LLMChain
from langchain.prompts import ChatPromptTemplate
from langchain.llms import OpenAI

# %% [markdown]
# Preprocessing function to remove stopwords and unecessary tokens from the text

# %%
def preprocess(text, stop_words):
    """
    Tokenizes and preprocesses the input text, removing stopwords and short
    tokens.

    Parameters:
        text (str): The input text to preprocess.
        stop_words (set): A set of stopwords to be removed from the text.
    Returns:
        list: A list of preprocessed tokens.
    """
    result = []
    for token in simple_preprocess(text, deacc=True):
        if token not in stop_words and len(token) > 3:
            result.append(token)
    return result

# %% [markdown]
# Used to get a list of topics from pdf

# %%
def get_topic_lists_from_pdf(file, num_topics, words_per_topic):
    """
    Extracts topics and their associated words from a PDF document using the
    Latent Dirichlet Allocation (LDA) algorithm.

    Parameters:
        file (str): The path to the PDF file for topic extraction.
        num_topics (int): The number of topics to discover.
        words_per_topic (int): The number of words to include per topic.

    Returns:
        list: A list of num_topics sublists, each containing relevant words
        for a topic.
    """
    # Load the pdf file
    loader = PdfReader(file)

    # Extract the text from each page into a list. Each page is considered a document
    documents= []
    for page in loader.pages:
        documents.append(page.extract_text())

    # Preprocess the documents
    nltk.download('stopwords')
    stop_words = set(stopwords.words(['english','spanish']))
    processed_documents = [preprocess(doc, stop_words) for doc in documents]

    # Create a dictionary and a corpus
    dictionary = corpora.Dictionary(processed_documents)
    corpus = [dictionary.doc2bow(doc) for doc in processed_documents]

    # Build the LDA model
    lda_model = LdaModel(
        corpus,
        #num_topics=num_topics,
        id2word=dictionary,
        passes=15
        )

    # Retrieve the topics and their corresponding words
    topics = lda_model.print_topics()#(num_words=words_per_topic)

    # Store each list of words from each topic into a list
    topics_ls = []
    for topic in topics:
        words = topic[1].split("+")
        topic_words = [word.split("*")[1].replace('"', '').strip() for word in words]
        topics_ls.append(topic_words)

    return topics_ls

# %% [markdown]
# Generates a description along with each major topic in the document

# %%
def topics_from_pdf(llm, file, num_topics, words_per_topic):
    """
    Generates descriptive prompts for LLM based on topic words extracted from a
    PDF document.

    This function takes the output of `get_topic_lists_from_pdf` function,
    which consists of a list of topic-related words for each topic, and
    generates an output string in bulleted nested list format.

    Parameters:
        llm (LLM): An instance of the Large Language Model (LLM) for generating
        responses.
        file (str): The path to the PDF file for extracting topic-related words.
    Returns:
        str: A response generated by the language model based on the provided
        topic words.
    """

    # Extract topics and convert them to string
    list_of_topicwords = get_topic_lists_from_pdf(file, num_topics,
                                                  words_per_topic)
    string_lda = ""
    for list in list_of_topicwords:
        string_lda += str(list) + "\n"

    # Create the template
    template_string = '''Describe the topic of each of the {num_topics}
        double-quote delimited lists in a simple sentence and also write down
        three possible different subthemes. The lists are the result of an
        algorithm for topic discovery.
        Do not provide an introduction or a conclusion, only describe the
        topics. Do not mention the word "topic" when describing the topics.
        Use the following template for the response.

        1: <<<(sentence describing the topic)>>>
        - <<<(Phrase describing the first subtheme)>>>
        - <<<(Phrase describing the second subtheme)>>>
        - <<<(Phrase describing the third subtheme)>>>

        2: <<<(sentence describing the topic)>>>
        - <<<(Phrase describing the first subtheme)>>>
        - <<<(Phrase describing the second subtheme)>>>
        - <<<(Phrase describing the third subtheme)>>>

        ...

        n: <<<(sentence describing the topic)>>>
        - <<<(Phrase describing the first subtheme)>>>
        - <<<(Phrase describing the second subtheme)>>>
        - <<<(Phrase describing the third subtheme)>>>

        Lists: """{string_lda}""" '''

    # LLM call
    prompt_template = ChatPromptTemplate.from_template(template_string)
    chain = LLMChain(llm=llm, prompt=prompt_template)
    response = chain.run({
        "string_lda" : string_lda,
        "num_topics" : num_topics
        })

    return response

# %% [markdown]
# API for gpt LLM

# %%
openai_key = "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"
llm = OpenAI(openai_api_key=openai_key, max_tokens=-1)

# %% [markdown]
# Extracting the text and preprocessing the pdf

# %%
file = "/content/Nutrition-and-India.pdf"
num_topics=25
words_per_topic=30
summary = topics_from_pdf(llm, file, num_topics, words_per_topic)
print(summary)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 1: Interventions focusing on lactation
# - Improving breastfeeding techniques
# - Encouraging breastfeeding education
# - Promoting skin-to-skin contact with newborns
#
# 2: Interventions to improve maternal health
# - Providing access to prenatal care
# - Educating mothers on proper nutrition during pregnancy
# - Offering support for postpartum depression
#
# 3: Levels of intervention for mental health
# - Individual therapy
# - Group therapy
# - Medication management
#
# 4: Lays food products
# - Potato chips
# - Sunflower seeds
# - Puffed snacks
#
# 5: Lactation and its benefits for infants
# - Improved immune system
# - Proper nutrition for growth and development
# - Bonding between mother and baby
#
# 6: Lactating mothers and their dietary needs
# - Adequate calorie intake
# - Consuming nutrient-rich foods
# - Staying hydrated
#
# 7: Knowledge acquisition in education
# - Active learning strategies
# - Critical thinking skills
# - Utilizing technology in the classroom
#
# 8: Janani Suraksha Yojana (JSY)
# - Promoting institutional deliveries
# - Providing financial assistance for prenatal and postnatal care
# - Addressing maternal and infant mortality rates
#
# 9: Ions and their role in cellular function
# - Sodium, potassium, calcium, and magnesium
# - Maintaining electrolyte balance
# - Nerve and muscle activity
#
# 10: Making healthy lifestyle choices
# - Eating a balanced diet
# - Exercising regularly
# - Getting enough sleep
#
# 11: Strategies for reducing stress and anxiety
# - Mindfulness practices
# - Exercise and physical activity
# - Seeking professional help when needed
#
# 12: Aims of Swachh Bharat Abhiyan (Clean India Mission)
# - Eliminating open defecation
# - Improving sanitation and hygiene practices
# - Promoting waste management and recycling
#
# 13: Social welfare schemes for children
# - Mid-day meal program
# - Education subsidies
# - Child protection services
#
# 14: Promoting girls' education
# - Providing equal access to education
# - Addressing barriers to girls' education
# - Encouraging girls' participation in STEM fields
#
# 15: Interventions to prevent and manage chronic diseases
# - Encouraging healthy lifestyle choices
# - Regular health screenings and check-ups
# - Managing health conditions through medication and lifestyle modifications
#
# 16: Interventions for addressing malnutrition
# - Nutrient supplementation programs
# - Promoting diverse and balanced diets
# - Addressing food insecurity
#
# 17: Levels of education and their importance
# - Primary education
# - Secondary education
# - Higher education
#
# 18: Strategies for improving maternal and child health
# - Prenatal and postnatal care
# - Vaccinations and immunizations
# - Family planning and birth spacing
#
# 19: Aims of the National Rural Health Mission (NRHM)
# - Improving access to healthcare in rural areas
# - Addressing health disparities
# - Training and deploying community health workers
#
# 20: Interventions to prevent and manage infectious diseases
# - Vaccination programs
# - Promoting hand hygiene and sanitation
# - Early detection and treatment
#
# 21: Promoting mental health and well-being
# - Encouraging self-care practices
# - Building resilience and coping skills
# - Increasing access to mental healthcare services
#
# 22: Roles and responsibilities of healthcare workers
# - Physicians, nurses, and other healthcare professionals
# - Providing patient care
# - Community health outreach and education
#
# 23: District-level interventions for community development
# - Infrastructure development
# - Social welfare programs
# - Promoting economic growth and employment opportunities
#
# 24: Strategies for reducing substance abuse
# - Education and awareness programs
# - Access to treatment and rehabilitation services
# - Addressing underlying mental health issues
#
# 25: Making environmentally sustainable choices
# - Reducing carbon footprint
# - Conserving resources
# - Promoting renewable energy sources

# %% [markdown]
# Using this summary to generate MCQs

# %%
type(summary)
# Out:
# str

# %%
from langchain.prompts import PromptTemplate
def generate_list(text):
  template=""""
  Store the topics and their respective subpoints combined into one element each of a list from the given CONTEXT.\
  In this way, format all the topics and their subpoints each into an element of a list.\
  Output the final list as the answer.

  The final response should be a list of Strings

  CONTEXT: {text}
  """
  model = OpenAI(openai_api_key=openai_key, max_tokens=-1)
  prompt = PromptTemplate(
    template= template,
    input_variables=["text"],
    )

  chain = prompt | model
  response = chain.invoke({"text":text})
  return response

# %% [markdown]
# Storing the output in a topics_list

# %%
topics=generate_list(summary)
import ast

# Convert the string to a list of strings
topics_list = ast.literal_eval(topics)

# %%
topics_list[15]
# Out:
# 'Interventions for addressing malnutrition - Nutrient supplementation programs - Promoting diverse and balanced diets - Addressing food insecurity'

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader(
    file_path="/content/Nutrition-and-India.pdf"
)
data=loader.load()

# %% [markdown]
# Create a vector database to store the questions

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Initialize Text Splitter for question generation
text_splitter_question_gen = RecursiveCharacterTextSplitter(chunk_size=3000, chunk_overlap=200)

# %%
from langchain.docstore.document import Document
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
# Split text into chunks for question generation
text_question_gen = ''
for page in data:
    text_question_gen += page.page_content
text_chunks_question_gen = text_splitter_question_gen.split_text(text_question_gen)

# %%
# Convert chunks into Documents for question generation
docs_question_gen = [Document(page_content=t) for t in text_chunks_question_gen]

# %%
# embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
from langchain.embeddings import HuggingFaceInferenceAPIEmbeddings
embeddings = HuggingFaceInferenceAPIEmbeddings(api_key="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",model_name="BAAI/bge-small-en-v1.5")
vector_store = Chroma.from_documents(docs_question_gen, embeddings)

# %% [markdown]
# Using Retrieval Chain and Multiple API calls to generate MCQs. Implementing reranking too

# %%
# Initialize retrieval chain for answer generation
import os
from langchain.chains import RetrievalQA
llm = OpenAI(openai_api_key=openai_key, max_tokens=-1)
from langchain_cohere import CohereRerank
from langchain.retrievers import ContextualCompressionRetriever
os.environ['COHERE_API_KEY']="QWe3cacVyfK7BQioAI1lwMUT8Eydbt3Xp0N2kwUF"
compressor = CohereRerank()
base_retriever=vector_store.as_retriever(k=5)
retriever=ContextualCompressionRetriever(base_compressor=compressor, base_retriever=base_retriever)
question_gen_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff",
                                                retriever=base_retriever)

# %% [markdown]
# Prompting to generate MCQs

# %%
text=""
for i in range(len(topics_list)):
  # Generate the string with the variable value
  question_string = f"""
  You are a UPSC Exam Expert in India. Your job is to test the knowledge of aspirants.\
  Generate 5-6 possible MCQ questions along with their options on the topic and summary {topics_list[i]}.\
  Here is the format which must be strictly followed for the generated MCQs:

      Q. The Question for the MCQ Framed
      (a) Option 1
      (b) Option 2
      (c) Option 3
      (d) Option 4


  """

  # Run the chain with the generated string
  answer = question_gen_chain.run(question_string)
  text += answer
# Out:
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# WARNING:chromadb.segment.impl.vector.local_hnsw:Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3

# %%
print(text)
# Out:
# 1. Q. Which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of a balanced diet
# (b) Inefficient PDS system
# (c) Availability of diverse and nutritious crops
# (d) Lack of awareness about nutritional requirements
#
# 2. Q. According to the National Family Health Survey -4, what percentage of children in India are stunted?
# (a) 33%
# (b) 50%
# (c) 19%
# (d) 10%
#
# 3. Q. Which of the following is NOT a goal of the POSHAN Abhiyan?
# (a) Reducing stunting in children
# (b) Improving the nutritional status of pregnant women
# (c) Increasing obesity rates in adults
# (d) Reducing low birth weight in newborns
#
# 4. Q. The National Nutrition Strategy aims to decrease all forms of malnutrition by which year?
# (a) 2020
# (b) 2025
# (c) 2030
# (d) 2050
#
# 5. Q. Which intervention is NOT a part of the POSHAN Abhiyan?
# (a) Encouraging skin-to-skin contact with newborns
# (b) Providing bi-annual vitamin A supplements for children
# (c) Promoting the consumption of fortified wheat flour
# (d) Training Auxiliary Nurse Midwives and ASHAs.
#
# 1. What is the main aim of the POSHAN Abhiyan?
# (a) To improve the nutritional status of children from 0-6 years.
# (b) To provide access to prenatal care for pregnant women.
# (c) To educate mothers on proper nutrition during pregnancy.
# (d) To offer support for postpartum depression.
#
# 2. Which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of awareness about nutritional requirements.
# (b) Inefficient PDS system.
# (c) Access to clean drinking water.
# (d) High female literacy rate.
#
# 3. According to the Global Nutrition Report, what percentage of the world's stunted children are in India?
# (a) 10%
# (b) 17%
# (c) 21%
# (d) 31%
#
# 4. Which of the following is NOT a part of the National Nutrition Strategy?
# (a) Decentralized approach.
# (b) Increase in supplementary nutrition during pregnancy.
# (c) Promotion of breastfeeding.
# (d) Convergence among various existing schemes.
#
# 5. What is the main objective of the Swasth Bharat Preraks in the POSHAN Abhiyan?
# (a) To provide access to prenatal care for pregnant women.
# (b) To coordinate with district officials for efficient execution of the Abhiyan.
# (c) To educate mothers on proper nutrition during pregnancy.
# (d) To offer support for postpartum depression.
#
# 6. What is the role of ICT tools in the POSHAN Abhiyan?
# (a) To monitor the implementation of the scheme.
# (b) To provide nutritional food items through PDS.
# (c) To promote the welfare of women farmers.
# (d) To teach nutrition as a compulsory topic in schools.
#
#  1. Which of the following interventions is NOT a part of the National Nutrition Strategy?
#  (a) Supplementary nutrition during pregnancy and lactation
#  (b) Promotion of breastfeeding
#  (c) Bi-annual vitamin A supplements for children
#  (d) Micro-nutrient supplements for women only
#
# 2. The key intervention in the POSHAN Abhiyaan is the use of ICT tools by which of the following?
# (a) Anganwadi workers
# (b) Auxiliary Nurse Midwives (ANM)
# (c) ASHA workers
# (d) All of the above
#
# 3. Which of the following is NOT a major cause of malnutrition in India?
# (a) Access to clean drinking water
# (b) Caste and social status
# (c) Lack of a balanced diet
# (d) Lack of awareness about nutritional requirements
#
# 4. Which of the following is NOT a target of the Poshan Abhiyan?
# (a) Reduce stunting by 2% per annum
# (b) Reduce undernutrition by 2% per annum
# (c) Reduce anemia among women by 2% per annum
# (d) Reduce low birth weight by 4% per annum
#
# 5. Which of the following is NOT a possible way forward for improving nutrition in India?
# (a) Providing improved training to ANM and ASHA workers
# (b) Promoting the growth of traditional crops like cereals
# (c) Designing mid-day meals based on local culture and geography
# (d) Implementing Annual Integrated Health, Nutrition and Swachh Bharat Mission action plans for all districts under the POSHAN Abhiyan
# 1. Which country has the highest number of stunted children in the world, according to UNICEF?
# (a) India
# (b) China
# (c) United States
# (d) Nigeria
#
# 2. Which initiative aims to reduce stunting, undernutrition, anemia, and low birth weight by specific percentages annually?
# (a) POSHAN Abhiyan
# (b) National Nutrition Strategy
# (c) Swasth Bharat Mission
# (d) NFHS-4
#
# 3. Which factor is NOT cited as a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Poor sanitation
# (c) Low female literacy
# (d) High consumption of diverse and nutritious crops
#
# 4. What is the primary goal of Lays' food products?
# (a) To promote healthy and diverse diets in India
# (b) To improve the nutritional status of children and women
# (c) To reduce the prevalence of obesity in adults
# (d) To provide employment opportunities for women farmers
#
# 5. Which food item is NOT mentioned as a part of Lays' product line?
# (a) Potato chips
# (b) Sunflower seeds
# (c) Puffed snacks
# (d) Millets
#
# 6. What is the target percentage for reducing stunting by the year 2022, according to POSHAN Abhiyan?
# (a) 20%
# (b) 25%
# (c) 30%
# (d) 35%
# 1. What is the main benefit of lactation for infants?
# (a) Improved immune system
# (b) Proper nutrition for growth and development
# (c) Bonding between mother and baby
# (d) All of the above
#
# 2. Which of the following is not a benefit of lactation for infants?
# (a) Improved immune system
# (b) Proper nutrition for growth and development
# (c) Bonding between mother and baby
# (d) Increased risk of allergic reactions
#
# 3. Lactation provides infants with _______.
# (a) Vitamins and minerals
# (b) Carbohydrates and fats
# (c) Proteins and fiber
# (d) All of the above
#
# 4. Which of the following is not a factor that can impact lactation?
# (a) Socio-cultural milieu
# (b) Access to clean drinking water
# (c) Female literacy
# (d) Social status and caste
#
# 5. What percentage of stunted children in the world are from India?
# (a) 10%
# (b) 17%
# (c) 21%
# (d) 31%
# 1. What is the aim of POSHAN Abhiyan?
# (a) To improve the nutritional status of children aged 0-6 years
# (b) To reduce stunting and anemia among adolescents
# (c) To provide training to ANM and ASHA workers
# (d) To promote the welfare of women farmers
#
# 2. What is the key intervention in the POSHAN Abhiyan?
# (a) Use of ICT tools by Anganwadi workers
# (b) Provision of fortified wheat flour through PDS
# (c) Implementation of Annual Integrated Health, Nutrition, and SBM action plans
# (d) Training of farmers on diverse and nutritious crops
#
# 3. What is the main cause of malnutrition in India?
# (a) Lack of awareness about nutritional requirements
# (b) Inefficient PDS system
# (c) Access to clean drinking water and sanitation
# (d) Poor diet consisting mainly of cereals
#
# 4. Which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of convergence among various existing schemes
# (b) Caste and social status
# (c) Lack of area-wise nutritional plan
# (d) Adequate calorie intake by lactating mothers
#
# 5. What percentage of women in India can be considered undernourished?
# (a) 20%
# (b) 21%
# (c) 23%
# (d) 25%
#
# 6. What is the primary aim of Poshan Abhiyan?
# (a) To reduce stunting and undernutrition among children
# (b) To provide adequate calorie intake for lactating mothers
# (c) To promote the welfare of women farmers
# (d) To decrease all forms of malnutrition by 2030.
#
# 1. Which of the following is NOT an active learning strategy?
# (a) Lecture-style teaching
# (b) Group discussions
# (c) Role-playing
# (d) Hands-on activities
#
# 2. Critical thinking skills are important in education because they help students to:
# (a) Memorize information better
# (b) Follow instructions more closely
# (c) Understand complex concepts and solve problems
# (d) Complete assignments faster
#
# 3. How can technology be utilized in the classroom to enhance learning?
# (a) Replacing traditional teaching methods entirely
# (b) Providing access to a variety of resources and information
# (c) Eliminating the need for homework
# (d) Allowing students to skip class and learn at home
#
# 4. Which of the following is NOT a way to promote knowledge acquisition in education?
# (a) Encouraging students to ask questions and think critically
# (b) Providing hands-on activities and real-life scenarios
# (c) Utilizing technology to increase student engagement
# (d) Discouraging students from participating in group discussions
#
# 5. In what ways can active learning strategies benefit students?
# (a) Developing independent thinking skills
# (b) Helping students to memorize information more easily
# (c) Decreasing student engagement and participation
# (d) Focusing on lecture-style teaching methods.
#
# 1. Which of the following is not a key aim of Janani Suraksha Yojana (JSY)?
# (a) Promoting institutional deliveries
# (b) Providing financial assistance for prenatal and postnatal care
# (c) Addressing maternal and infant mortality rates
# (d) Reducing malnutrition in children
#
# 2. How often are micro-nutrient supplements and de-worming provided to children under JSY?
# (a) Once a year
# (b) Twice a year
# (c) Three times a year
# (d) They are not provided under JSY
#
# 3. How does JSY aim to reduce maternal and infant mortality rates?
# (a) By promoting home births
# (b) By providing financial assistance for hospital deliveries
# (c) By increasing the number of children per family
# (d) By promoting traditional birthing practices
#
# 4. Which of the following is not a factor contributing to malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Low female literacy rates
# (c) Inefficient PDS system
# (d) High consumption of diverse and nutritious crops
#
# 5. What is the target reduction for low birth weight under the POSHAN Abhiyan?
# (a) 1%
# (b) 2%
# (c) 3%
# (d) 4%
#
# 6. Which of the following is not a key intervention under the POSHAN Abhiyan?
# (a) Use of ICT tools by Anganwadi workers
# (b) Convergence with various programs
# (c) Implementation of annual action plans for districts
# (d) Promotion of traditional birthing practices
#
# 1. Which of the following minerals plays a crucial role in maintaining electrolyte balance in the body?
# (a) Sodium
# (b) Iron
# (c) Potassium
# (d) Calcium
#
# 2. Which mineral is essential for nerve and muscle activity?
# (a) Magnesium
# (b) Iron
# (c) Calcium
# (d) Zinc
#
# 3. Which mineral is important for cellular function and is also known as the "messenger of life"?
# (a) Potassium
# (b) Calcium
# (c) Sodium
# (d) Magnesium
#
# 4. Which mineral is responsible for maintaining proper muscle contraction and relaxation?
# (a) Calcium
# (b) Zinc
# (c) Sodium
# (d) Iron
#
# 5. Which of the following minerals can help prevent muscle cramps and spasms?
# (a) Sodium
# (b) Magnesium
# (c) Iron
# (d) Potassium
#
# 6. Which mineral is crucial for the transmission of nerve impulses and maintaining heart rhythm?
# (a) Iron
# (b) Calcium
# (c) Sodium
# (d) Potassium
# Q. Which of the following is NOT a major cause of malnutrition?
# (a) Lack of access to clean drinking water
# (b) Caste and social status
# (c) Consumption of a balanced diet
# (d) Inefficient PDS system
#
# Q. What is the main aim of POSHAN Abhiyan?
# (a) To improve the nutritional status of children aged 0-6 years
# (b) To reduce stunting, undernutrition, anemia, and low birth weight
# (c) To promote the welfare of women farmers
# (d) To ensure that nutrition is taught as a compulsory topic in schools
#
# Q. According to the National Family Health Survey -4, what percentage of adults in India are either obese or overweight?
# (a) 20%
# (b) 30%
# (c) 40%
# (d) 50%
#
# Q. What is the top priority of the National Nutrition Strategy?
# (a) To decrease all forms of malnutrition by 2030
# (b) To strengthen the ownership of Panchayati Raj institutions and urban local bodies
# (c) To promote greater flexibility and decision making at the state, district, and local levels
# (d) To tie together supplementary nutrition, promotion of breastfeeding, and vitamin A supplements
#
# Q. How does the POSHAN Abhiyan aim to reduce stunting by 2022?
# (a) By promoting the welfare of women farmers
# (b) By deploying Swasth Bharat Preraks in each district
# (c) By ensuring service delivery and interventions through technology
# (d) By providing training to ANM, ASHA, and Anganwadi workers
#
# Q. What is the role of Swasth Bharat Preraks in the implementation of POSHAN Abhiyan?
# (a) To provide training to ANM, ASHA, and Anganwadi workers
# (b) To promote the welfare of women farmers
# (c) To deploy in each district for coordinating with district officials
# (d) To ensure convergence with various programmes and schemes.
# 1. Q. Which of the following is NOT a recommended strategy for reducing stress and anxiety?
# (a) Mindfulness practices
# (b) Exercise and physical activity
# (c) Seeking professional help when needed
# (d) Avoiding social interactions
#
# 2. Q. Which of the following is a mindfulness practice that can help reduce stress and anxiety?
# (a) Watching television
# (b) Eating junk food
# (c) Going for a walk
# (d) Meditation
#
# 3. Q. How often should one engage in physical activity to help reduce stress and anxiety?
# (a) Once a week
# (b) Three times a week
# (c) Every day
# (d) Only when feeling stressed
#
# 4. Q. Seeking professional help is recommended when stress and anxiety become:
# (a) A daily occurrence
# (b) A weekly occurrence
# (c) A monthly occurrence
# (d) A yearly occurrence
#
# 5. Q. Which of the following is NOT a recommended exercise for reducing stress and anxiety?
# (a) Yoga
# (b) Running
# (c) Weightlifting
# (d) Sitting for long periods of time
#
# 6. Q. What is one potential benefit of seeking professional help for stress and anxiety?
# (a) It is free of cost
# (b) It can provide a quick fix solution
# (c) It can help identify underlying issues
# (d) It can be done remotely via phone or email
#
# Q. The Swachh Bharat Abhiyan aims to achieve all of the following goals EXCEPT:
# (a) Eliminating open defecation
# (b) Improving sanitation and hygiene practices
# (c) Promoting waste management and recycling
# (d) Reducing air pollution
#
# Q. The Swachh Bharat Abhiyan was launched by which Prime Minister of India?
# (a) Indira Gandhi
# (b) Rajiv Gandhi
# (c) Atal Bihari Vajpayee
# (d) Narendra Modi
#
# Q. In which year was the Swachh Bharat Abhiyan launched?
# (a) 2011
# (b) 2012
# (c) 2014
# (d) 2016
#
# Q. The Swachh Bharat Abhiyan aims to make India open-defecation free by which year?
# (a) 2019
# (b) 2022
# (c) 2025
# (d) 2030
#
# Q. Which of the following is NOT a key intervention under the Swachh Bharat Abhiyan?
# (a) Construction of toilets
# (b) Promotion of hand washing
# (c) Promotion of safe disposal of waste
# (d) Distribution of free bicycles for transportation
#
# Q. The Swachh Bharat Abhiyan is a part of which larger government initiative?
# (a) National Health Mission
# (b) Make in India
# (c) Digital India
# (d) Beti Bachao Beti Padhao
#
# Q. Which of the following is NOT a part of the National Nutrition Strategy?
# (a) Supplementary nutrition during pregnancy and lactation
# (b) Promotion of breastfeeding
# (c) Mid-day meal program
# (d) Bi-annual vitamin A supplements for children
#
# Q. Which of the following is NOT a cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Low levels of female literacy
# (c) Efficient PDS system
# (d) Lack of awareness about nutritional requirements
#
# Q. Which of the following is NOT a goal of the Poshan Abhiyan?
# (a) Reducing stunting among children
# (b) Convergence of state and district implementation plans
# (c) Improving the nutritional status of pregnant women
# (d) Increasing the number of Swasth Bharat Preraks in each district
#
# Q. The Poshan Abhiyan aims to reduce stunting from 38.4% to what percentage by 2022?
# (a) 25%
# (b) 30%
# (c) 20%
# (d) 35%
#
# Q. Which of the following is NOT a key intervention in the Poshan Abhiyan?
# (a) Use of ICT tools by Anganwadi workers
# (b) Convergence with various programs
# (c) Deployment of Swasth Bharat Preraks in each district
# (d) Implementation of Annual Integrated Health, Nutrition, and Swachh Bharat Mission action plans
#   Q. According to the National Family Health Survey-4, what percentage of children in India are stunted?
#   (a) 10%
#   (b) 20%
#   (c) 30%
#   (d) 40%
#
#   Q. Which of the following is a major cause of malnutrition in India?
#   (a) Lack of access to clean drinking water
#   (b) Lack of awareness about nutritional requirements
#   (c) Inefficient PDS system
#   (d) All of the above
#
#   Q. According to the Global Nutrition Report, what percentage of the world's stunted children are in India?
#   (a) 10%
#   (b) 20%
#   (c) 30%
#   (d) 40%
#
#   Q. What is the chief aim of the Poshan Abhiyan mission?
#   (a) To improve the nutritional status of children from 0-6 years
#   (b) To promote equal access to education for girls
#   (c) To encourage girls' participation in STEM fields
#   (d) To reduce low birth weight in children
#
#   Q. Which of the following is a key intervention in the Poshan Abhiyan scheme?
#   (a) Training for ANM and ASHA workers
#   (b) Deployment of Swasth Bharat Preraks in each district
#   (c) Use of ICT tools by Anganwadi workers
#   (d) All of the above
#
#   Q. According to the National Nutrition Strategy, what is the target year for decreasing all forms of malnutrition?
#   (a) 2020
#   (b) 2025
#   (c) 2030
#   (d) 2040
# Q. What is the main aim of the POSHAN Abhiyan?
# (a) To improve the nutritional status of children
# (b) To tackle chronic diseases
# (c) To promote healthy lifestyle choices
# (d) To improve access to clean drinking water
#
# Q. According to the National Family Health Survey -4, what percentage of Indian adults are either obese or overweight?
# (a) 10%
# (b) 20%
# (c) 30%
# (d) 40%
#
# Q. What is the main cause of malnutrition in India?
# (a) Inefficient PDS system
# (b) Lack of awareness about nutritional requirements
# (c) Lack of balanced diet
# (d) All of the above
#
# Q. Which of the following is NOT a major cause of malnutrition in India?
# (a) Access to clean drinking water
# (b) Caste and social status
# (c) Lack of area-wise nutritional plan
# (d) Availability of diverse and nutritious crops
#
# Q. Which initiative aims to decrease all forms of malnutrition by 2030?
# (a) National Nutrition Strategy
# (b) Swasth Bharat Preraks
# (c) POSHAN Abhiyan
# (d) Mahatma Gandhi National Rural Employment Guarantee Scheme
#
# 1. Which of the following is not a major cause of malnutrition?
# (a) Lack of access to clean drinking water
# (b) Female literacy
# (c) Caste and social status
# (d) Balanced diet
#
# 2. Which of the following is not a target of the POSHAN Abhiyan?
# (a) Reduce stunting by 2% per annum
# (b) Reduce undernutrition by 2% per annum
# (c) Reduce anemia by 3% per annum
# (d) Reduce low birth weight by 4% per annum
#
# 3. Which of the following is not a suggested way forward for addressing malnutrition?
# (a) Improved training for ANM, ASHA, and Anganwadi workers
# (b) Promotion of diverse and nutritious crops
# (c) Designing mid-day meals based on local culture and geography
# (d) Increasing restrictions on the use of technology in nutrition programs
#
# 4. Which of the following is not a key intervention in the POSHAN Abhiyan?
# (a) Use of ICT tools by Anganwadi workers
# (b) Deployment of Swasth Bharat Preraks in each district
# (c) Convergence with various existing schemes
# (d) Increasing awareness about the importance of a healthy and diverse diet
#
# 5. Which of the following is not a suggested way to improve nutrition and food security?
# (a) Developing and implementing annual integrated action plans
# (b) Ensuring availability of nutritious food items through PDS
# (c) Promoting the welfare of women farmers
# (d) Making nutrition education a compulsory topic in schools
#
# 6. According to the UNICEF, India ranks ___ among countries with the largest number of underweight children.
# (a) 5
# (b) 10
# (c) 15
# (d) 20
#
# 1. Q. What is the primary aim of the POSHAN Abhiyan mission in India?
# (a) To improve the nutritional status of children and women
# (b) To increase the literacy rate among girls
# (c) To promote healthy eating habits among the population
# (d) To reduce the prevalence of obesity in adults
#
# 2. Q. According to the National Family Health Survey -4, which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Illiteracy among women
# (c) Caste and social status
# (d) Consumption of a balanced diet
#
# 3. Q. Which age group is targeted by the Swasth Bharat Preraks under the POSHAN Abhiyan mission?
# (a) 0-6 years
# (b) Adolescents
# (c) Pregnant women
# (d) Elderly population
#
# 4. Q. What is the primary goal of the National Nutrition Strategy in India?
# (a) To decrease all forms of malnutrition by the year 2030
# (b) To increase the production of nutritious crops
# (c) To promote the welfare of women farmers
# (d) To improve sanitation and access to clean drinking water
#
# 5. Q. According to UNICEF, in terms of stunted and underweight children, where does India rank among countries in the world?
# (a) 5th
# (b) 10th
# (c) 15th
# (d) 20th
#
# 6. Q. Which of the following is NOT a major indicator of malnutrition in India, according to NFHS-4 data?
# (a) Stunting in children
# (b) Obesity in adults
# (c) Anemia in women
# (d) Low birth weight in newborns
#
# 1. Which of the following is not a component of the National Nutrition Strategy?
# (a) Convergence of state and district implementation plans
# (b) Supplementary nutrition during pregnancy and lactation
# (c) Mid-day meals designed based on local culture and geography
# (d) Monthly biometric monitoring of pregnant women and lactating mothers
#
# 2. According to NFHS-4 data, what percentage of children in India are stunted?
# (a) 20%
# (b) 31%
# (c) 38.4%
# (d) 50%
#
# 3. Which of the following is not a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Inefficient PDS system
# (c) Female literacy
# (d) High consumption of diverse and nutritious crops
#
# 4. What is the chief aim of the Poshan Abhiyan mission?
# (a) To improve the nutritional status of children from 0-6 years
# (b) To promote the welfare of women farmers
# (c) To reduce the prevalence of obesity and overweight in adults
# (d) To provide free vaccinations and immunizations for all children under 5 years old
#
# 5. According to the National Nutrition Strategy, what is the primary target age group for reducing malnutrition?
# (a) Adolescents
# (b) Pregnant women
# (c) Children under 5 years old
# (d) All age groups are targeted equally
#
# 6. How many Swasth Bharat Preraks will be deployed under the Poshan Abhiyan?
# (a) 1 per district
# (b) 5 per district
# (c) 10 per district
# (d) 20 per district
# 1. Q. Which of the following is NOT an aim of the National Rural Health Mission (NRHM)?
# (a) Improving access to healthcare in rural areas
# (b) Addressing health disparities
# (c) Providing free healthcare services to urban populations
# (d) Training and deploying community health workers
#
# 2. Q. In which areas does the National Rural Health Mission (NRHM) primarily focus on improving healthcare access?
# (a) Urban areas
# (b) Coastal areas
# (c) Rural areas
# (d) All of the above
#
# 3. Q. The National Rural Health Mission (NRHM) aims to address which of the following in regards to healthcare?
# (a) Social disparities
# (b) Economic disparities
# (c) Gender disparities
# (d) All of the above
#
# 4. Q. What is the role of community health workers under the National Rural Health Mission (NRHM)?
# (a) Providing healthcare services in urban areas
# (b) Addressing health disparities in rural areas
# (c) Training and deploying healthcare workers in rural areas
# (d) Addressing economic disparities in healthcare access
#
# 5. Q. Which of the following is NOT a potential solution for improving healthcare access in rural areas under the National Rural Health Mission (NRHM)?
# (a) Training and deploying community health workers
# (b) Providing free healthcare services to urban populations
# (c) Addressing social and economic disparities
# (d) Building more hospitals and clinics in rural areas
# Q. What is the chief aim of the Poshan Abhiyan mission in India?
# (a) To improve maternal health
# (b) To promote education for girls
# (c) To reduce stunting, undernutrition, anemia, and low birth weight
# (d) To increase access to clean drinking water
#
# Q. According to NFHS-4 data, what percentage of adults in India are considered overweight or obese?
# (a) 10%
# (b) 19%
# (c) 21%
# (d) 50%
#
# Q. What is the main role of Swasth Bharat Preraks in the Poshan Abhiyan mission?
# (a) To coordinate with district officials
# (b) To provide medical treatment
# (c) To distribute vaccines
# (d) To educate children about nutrition
#
# Q. What is the main cause of malnutrition in India?
# (a) Lack of access to clean water
# (b) Genetic predisposition
# (c) Limited food availability
# (d) Socio-cultural factors
#
# Q. Which of the following is NOT a key intervention in the Poshan Abhiyan scheme?
# (a) Use of ICT tools by Anganwadi workers
# (b) Distribution of fortified wheat flour
# (c) Implementation of annual integrated health plans
# (d) Promotion of balanced diet in schools
# 1. Q. Which of the following initiatives aims to improve the nutritional status of children from 0-6 years, Adolescent Girls, Pregnant Women and Lactating Mothers in India?
# (a) Poshan Abhiyan
# (b) National Nutrition Strategy
# (c) Global Nutrition Report
# (d) National Family Health Survey
# 2. Q. According to the National Family Health Survey -4 (NFHS-4), what percentage of adults in India are considered undernourished?
# (a) 20%
# (b) 21%
# (c) 23%
# (d) 50%
# 3. Q. Which of the following is not a major cause of malnutrition in India?
# (a) Lack of awareness about nutritional requirements
# (b) Inefficient PDS system
# (c) Availability of diverse and nutritious crops
# (d) Lack of convergence among existing schemes
# 4. Q. Which of the following is not a goal of Poshan Abhiyan?
# (a) Reducing stunting among children
# (b) Reducing low birth weight among infants
# (c) Increasing access to mental healthcare services
# (d) Reducing anemia among women and children
# 5. Q. What is the rank of India in terms of the highest number of stunted children in the world, as per the UNICEF?
# (a) 10
# (b) 17
# (c) 31
# (d) 50
# 6. Q. Which of the following is not a key intervention under Poshan Abhiyan?
# (a) Use of ICT tools by Anganwadi workers
# (b) Convergence with various government schemes
# (c) Promotion of breastfeeding
# (d) Providing financial assistance to farmers for growing diverse crops
#
# 1. Q. Which of the following is NOT a role of healthcare workers in providing patient care?
# (a) Administering medications
# (b) Diagnosing illnesses
# (c) Educating patients about preventive care
# (d) Performing surgeries
#
# 2. Q. Which of the following is NOT a responsibility of physicians in providing patient care?
# (a) Prescribing medication
# (b) Monitoring vital signs
# (c) Developing treatment plans
# (d) Cleaning and maintaining medical equipment
#
# 3. Q. Which of the following is a responsibility of nurses in providing patient care?
# (a) Performing surgeries
# (b) Interpreting lab results
# (c) Administering anesthesia
# (d) Providing emotional support to patients
#
# 4. Q. What is the role of healthcare professionals in community health outreach and education?
# (a) Providing medical treatment to community members
# (b) Educating community members about healthy lifestyle choices
# (c) Conducting medical research on community health issues
# (d) Recruiting volunteers for healthcare programs
#
# 5. Q. Which of the following is NOT a responsibility of healthcare workers in community health outreach and education?
# (a) Developing educational materials
# (b) Conducting health screenings
# (c) Collecting community health data
# (d) Administering vaccines
#
# 6. Q. What is the primary goal of community health outreach and education programs?
# (a) To provide free medical care to community members
# (b) To educate community members about healthy behaviors
# (c) To recruit healthcare professionals for underserved areas
# (d) To conduct medical research on community health issues
#
# 1. Which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Lack of female literacy
# (c) Efficient PDS system
# (d) Lack of awareness about nutritional requirements
#
# 2. Which age group is targeted for bi-annual deworming under the National Nutrition Strategy?
# (a) 0-6 years
# (b) 6-10 years
# (c) 9 months to 5 years
# (d) 5-10 years
#
# 3. Which organization estimates that if women farmers had the same resources as men, it would lead to 150 million fewer hungry people?
# (a) World Health Organization
# (b) Food and Agriculture Organization
# (c) United Nations Children's Fund
# (d) United Nations Development Programme
#
# 4. What is the key intervention in the Poshan Abhiyan scheme?
# (a) Use of ICT tools by Anganwadi workers
# (b) Convergence with various programmes
# (c) Deployment of Swasth Bharat Preraks
# (d) Improved training for ANMs and ASHA workers
#
# 5. What is the chief aim of the Poshan Abhiyan?
# (a) To improve the nutritional status of children from 0-6 years
# (b) To promote economic growth and employment opportunities
# (c) To reduce stunting, undernutrition, and anemia
# (d) To ensure service delivery and interventions through technology
#
# 6. Which of the following is a key component of the National Nutrition Strategy?
# (a) Decentralized approach
# (b) Centralized approach
# (c) Top-down decision making
# (d) Limited involvement of Panchayati Raj institutions
#
#
# 1. What is the main objective of the POSHAN Abhiyan?
# (a) To reduce stunting among children
# (b) To improve the nutritional status of pregnant women
# (c) To provide access to treatment for substance abuse
# (d) To promote awareness about mental health issues
#
# 2. According to the National Family Health Survey, what percentage of children in India are stunted?
# (a) 20%
# (b) 33%
# (c) 50%
# (d) 60%
#
# 3. Which of the following is NOT a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water
# (b) Inefficient Public Distribution System
# (c) Lack of awareness about nutritional requirements
# (d) High rate of obesity among adults
#
# 4. Which of the following is NOT a component of the National Nutrition Strategy?
# (a) Decentralized approach
# (b) Strengthening of Panchayati Raj institutions
# (c) Convergence of state and district implementation plans
# (d) Providing financial support to farmers for growing diverse crops
#
# 5. What is the main target of the Poshan Abhiyan?
# (a) Reducing substance abuse
# (b) Improving the health of women and children
# (c) Providing employment opportunities for women
# (d) Addressing mental health issues in rural areas
#
# 6. Which of the following is NOT a suggested way forward to improve nutrition in India?
# (a) Give training to ANM and ASHA workers
# (b) Promote diverse and nutritious crops
# (c) Design mid-day meals based on regional conditions
# (d) Increase the price of food items through PDS.
# 1. What is the primary aim of the National Nutrition Strategy in India?
# (a) To decrease the prevalence of all forms of malnutrition by 2030
# (b) To promote the use of ICT tools for efficient monitoring of nutrition initiatives
# (c) To reduce stunting, undernutrition, and anemia among young children, women, and adolescent girls
# (d) To improve the health and nutrition indicators of India's population
#
# 2. Which of the following is a major cause of malnutrition in India?
# (a) Lack of access to clean drinking water and sanitation
# (b) Inefficient Public Distribution System (PDS)
# (c) Lack of awareness about nutritional requirements
# (d) All of the above
#
# 3. According to the UNICEF, where does India rank in terms of the number of stunted children in the world?
# (a) 10
# (b) 17
# (c) 31
# (d) 1
#
# 4. Which of the following is NOT a key intervention under the POSHAN Abhiyan?
# (a) Convergence with various programs such as Anganwadi Services and National Health Mission
# (b) Deployment of Swasth Bharat Preraks in each district
# (c) Promotion of renewable energy sources
# (d) Use of ICT tools for easy monitoring and implementation
#
# 5. What is the primary aim of the Poshan Abhiyan?
# (a) To improve the nutritional status of children from 0-6 years, Adolescent Girls, Pregnant Women and Lactating Mothers
# (b) To reduce stunting, undernutrition and anemia among young children, women and adolescent girls
# (c) To promote the welfare of women farmers
# (d) To ensure convergence of state and district implementation plans for various health and nutrition initiatives
#
# 6. Which of the following is a key component of the National Nutrition Strategy?
# (a) Decentralized approach for greater flexibility and decision making at the state, district and local levels
# (b) Promotion of balanced diets and diverse food options
# (c) Implementation of annual integrated action plans for all districts under the POSHAN Abhiyan
# (d) All of the above

# %%
|
